# %% [markdown]
# ## Dimensionality Reduction: PCA
#
# Let's explore **Principal Component Analysis**, which is an extremely useful dimensionality reduction technique.
#
# Most common applications of PCA are:
# 1. Compression: Reduce memory needed to store data, speed up learning algorithm.
# 2. Visualization: Plot n dimensional data in 2D or 3D
#
# **PCA Goal** : Reduce from n-Dim to k-Dim, find k direction vectors (u1, u2,...,uk) onto which to project the data, so as to minimize the projection error.

# %%
from __future__ import print_function, division

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

import seaborn as sns; sns.set()

# %% [markdown]
# Let's visualize a 2D dataset

# %%
np.random.seed(1)
X = np.dot(np.random.random(size=(2,2)), np.random.normal(size=(2,200))).T
plt.plot(X[:, 0], X[:, 1], 'o')
plt.axis('equal');

# %% [markdown]
# We can see that there is a definite trend in the data. What PCA seeks to do is to find the **Principal Axes** in the data and explain how important those axes are in describing the data distribution.

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca.fit(X)
print(pca.explained_variance_)
print(pca.components_)
# Out:
# [ 0.75871884  0.01838551]
# [[ 0.94446029  0.32862557]
#  [ 0.32862557 -0.94446029]]

# %% [markdown]
# To see what these numbers mean, let's view them as vectors plotted on top of the data.

# %%
plt.plot(X[:, 0], X[:, 1], 'o', alpha=0.5)
for length, vector in zip(pca.explained_variance_, pca.components_):
    v = vector * 3 * np.sqrt(length)
    plt.plot([0, v[0]], [0, v[1]], 'k', lw=3)
plt.axis('equal');

# %% [markdown]
# Notice that one vector is longer than the other. This tells us that the longer vector direction in the data is more "important" than the shorter direction. The *explained variance* quantifies this measure of "importance" in direction.
#
# Another way to think of it is that the second principal component could be **completely ignored** without much loss of information.
#
# Let's see what our data looks like if we only retain **95% of the variance**.

# %%
clf = PCA(0.95) # retain 95% of variance
X_trans = clf.fit_transform(X)
print(X.shape)
print(X_trans.shape)
# Out:
# (200, 2)
# (200, 1)

# %% [markdown]
# By specifying that we want to throw away 5% of the variance, the data is now **compressed** by a factor of **50%**.
#
# Let's see what the data looks like after this compression.

# %%
X_new = clf.inverse_transform(X_trans)
plt.plot(X[:, 0], X[:, 1], 'o', alpha=0.2)
plt.plot(X_new[:, 0], X_new[:, 1], 'ob', alpha=0.8)
plt.axis('equal');

# %% [markdown]
# The light points are the original data, while the dark blue points are the projected version. We notice in the above plot that, after truncating 5% of the variance of this dataset and then reprojecting it, only the "most important" features of the data are maintained and we were also able to compress the data by 50%.
#
# This is the sense in which **Dimensionality Reduction** works: If you can approximate a data set in a lower dimension, you can often have an easier time visualizing it or fitting complicated models to the data.
#
# ## Application of PCA to Digits
#
# The dimensionality reduction might seem a bit abstract in two dimensions, but the projection and dimensionality reduction can be extremely useful when visualizing high-dimensional data. Let's take a quick look at the application of PCA to the digits data.

# %%
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.data
y = digits.target

pca = PCA(2) # projects from 64 to 2 dimensions
Xproj = pca.fit_transform(X)
print(X.shape)
print(Xproj.shape)
# Out:
# (1797, 64)
# (1797, 2)

# %%
plt.scatter(Xproj[:, 0], Xproj[:, 1], c=y, edgecolors='none', alpha=0.5,
           cmap=plt.cm.get_cmap('nipy_spectral', 10))
plt.colorbar();

# %% [markdown]
# This gives us an idea of the relationship between the digits. Essentially, we have found the optimal stretch and rotation in 64-D space that allows us to see the layout of the digits, **without reference** to the labels.

# %% [markdown]
# ## What do the components mean?
#
# PCA is a very useful dimensionality reduction algorithm, because it has a very intutive interpretation via *eigenvectors*. The input data is represented as a vector. For e.g. in case of digits, data looks like:
#
#                 x = [x1, x2, ...,xn]
#
# but what this really means is:
#
#                 image(x) = x1.(pixel~1) + x2.(pixel~2)+...
#
# if we reduce the dimensionality in the pixel space to (say) 6, we recover only a partial image:

# %%
from fig_code.figures import plot_image_components

sns.set_style('white')
plot_image_components(digits.data[0])

# %% [markdown]
# But, the pixel-wise representation is not the only choice. We can also use other basis functions, and write something like
#
#                   image(x) = mean + x1.(basis~1) + x2.(basis~2) + ...
#
# What PCA does is to choose optimal **basis functions** so that only a few are needed to get a reasonable approximation. The low dimensional representation of our data is the coefficients of this series, and the approximate reconstruction is the result of the sum:

# %%
from fig_code.figures import plot_pca_interactive
plot_pca_interactive(digits.data)

# %% [markdown]
# Here we see that with only six PCA components, we recover a reasonable approximation of the input.
#
# Thus we see that PCA can be viewed from two angles. It can be viewed as **dimenstionality reduction**, or it can be viewed as a form of **lossy data compression** where the loss favors noise. In this way, PCA can be used as a **filtering** process as well.

# %% [markdown]
# ### Choosing the Number of Components
#
# To figure out how much raw information has been thrown away, we can look into **explained variance** as a function of the components:

# %%
sns.set()
pca = PCA().fit(X)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %% [markdown]
# Here we see that our 2-Dim projection loses a lot of information(as measured by the explained variance) and that we would need about 20 components to retain 90% of the variance. Looking at the plot above can help us understand the level of redundancy present in multiple observations.

# %% [markdown]
# ## PCA as data compression
#
# PCA can be used for data compression. Using a small **n component** allows us to represent a high dimensional point as a sum of just a few principal vector components.
#
# Here's what a single digit looks like as you change the number of components:

# %%
fig, axes = plt.subplots(8, 8, figsize=(8,8))
fig.subplots_adjust(hspace=0.1, wspace=0.1)

for i, ax in enumerate(axes.flat):
    pca = PCA(i + 1).fit(X)
    im = pca.inverse_transform(pca.transform(X[20:21]))
    
    ax.imshow(im.reshape((8,8)), cmap='binary')
    ax.text(0.95, 0.05, 'n={0}'.format(i + 1), ha='right',
           transform=ax.transAxes, color='green')
    ax.set_xticks([])
    ax.set_yticks([])

# %% [markdown]
# Let's take another look at this by using Ipython interact functionality to view the reconstruction of several imaes at once:

# %%
from IPython.html.widgets import interact

def plot_digits(n_components):
    fig = plt.figure(figsize=(8,8))
    plt.subplot(1, 1, 1, frameon=False, xticks=[], yticks=[])
    nside = 10
    
    pca = PCA(n_components).fit(X)
    Xproj = pca.inverse_transform(pca.transform(X[:nside ** 2]))
    Xproj = np.reshape(Xproj, (nside, nside, 8, 8))
    total_var = pca.explained_variance_ratio_.sum()
    
    im = np.vstack([np.hstack([Xproj[i, j] for j in range(nside)])
                   for i in range(nside)])
    
    plt.imshow(im)
    plt.grid(False)
    plt.title("n={0}, variance = {1:.2f}".format(n_components, total_var),
             size=18)
    plt.clim(0, 16)

interact(plot_digits, n_components=[1, 64], nside=[1, 8]);
